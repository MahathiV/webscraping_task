# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as bs
from splinter.exceptions import ElementDoesNotExist
import traceback

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path,headless=False)

# %%
#url = "https://find.plasticsurgery.org/"
url="https://find.plasticsurgery.org/default.aspx?lat=29.7598976&lon=-95.4073088&page=1"
browser.visit(url)

# %%
html = browser.html
soup = bs(html,'html.parser')
#soup

# %%
#soup.find(id="findSurgeon").find(id="cphMainContent_pnlResults").find(id="cphMainContent_divSearchResultsCol")
#soup.find(id="findSurgeon").find(id="cphMainContent_divSearchResultsCol").find_all("tbody")[0]
#soup.find(id="findSurgeon").find(id="cphMainContent_pnlResults").find(id="cphMainContent_divSearchResultsCol")

# %%
c=["State","City","Highlighted Profile","Phone","Email","Website"]

# %%
df = pd.DataFrame(columns=c)

# %%
df
# Out:
# Empty DataFrame
# Columns: [State, City, Highlighted Profile, Phone, Email, Website]
# Index: []

# %%
#surgeon_name = soup.find(id="findSurgeon").find(id="cphMainContent_divSearchResultsCol").find(class_="RadAjaxPanel")

# %%
names = []
phones = []
websites = []

for x in range(1,9):
    url=f"https://find.plasticsurgery.org/default.aspx?lat=29.7598976&lon=-95.4073088&page={x}"
    browser.visit(url)
    html = browser.html
    soup = bs(html,'html.parser')
    
    surgeon = soup.find(id="findSurgeon").find(id="cphMainContent_divSearchResultsCol").find(class_="RadAjaxPanel")
    print(f"----------page : {x}---------")
    
    for s in surgeon.find_all("h3"):
        names.append(s.text.strip())
        print(s.text.strip())
   
    for p in surgeon.find_all("p",itemprop="telephone"):
        phones.append(p.text.strip())
        print(p.text.strip())
   
    for a in surgeon.find_all("tbody"):
        websites.append(a.find("a").get("href"))
        print(a.find("a").get("href"))
# Out:
# ----------page : 1---------
# Scott Reis, MD
# Carlton Perry, MD
# Forrest Roth, M.D., F.A.C.S.
# Edward Lee, MD
# Rukmini Rednam, MD
# Eugenio Aguilar, III, MD
# Sean Boutros, MD
# Camille Cash, MD
# Michael Ciaravino, MD
# Robert Steely, MD
# Bruce Smith, MD
# Donald Collins, Jr., MD
# (713) 791-0070
# (713) 522-8228
# (713) 559-9300
# (713) 999-1321
# (713) 791-0700
# (713) 521-4777
# (713) 791-0700
# (713) 571-0600
# (713) 627-1200
# (713) 622-6500
# (713) 659-2700
# (713) 650-0800
# http://www.plasticsurgery.org/md/dr-scott-reis.html
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# http://www.plasticsurgery.org/md/ciaravino.html
# javascript:;
# javascript:;
# http://www.plasticsurgery.org/md/donald-collins-jr-md.html
# ----------page : 2---------
# Wilberto Cortes, MD
# Steven Kronowitz, MD
# Michael Streitmann, MD
# Jason Bailey, MD
# Mark Schusterman, MD
# Lisa Santos, MD
# German Newall, MD
# Henry Mentz, MD
# Christopher Patronella, MD
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# http://www.plasticsurgery.org/md/james-f-boynton-md.html
# ----------page : 7---------
# Philip Yosowitz, MD
# Gregory Reece, MD
# Cain Linville, MD
# Shitel Patel, MD
# Dexter Blome, MD, Ph.D
# Mark Edelman, MD
# Andrew Lyos, MD
# Michael Streitmann, MD
# Ravi Somayazula, DO
# Erika Sato, MD
# Marc Sarcia, MD
# David Altamira, MD
# (713) 797-1488
# (713) 563-8500
# (713) 678-0019
# (832) 835-1131
#
# (713) 365-9990
# (713) 799-8989
#
# (281) 242-1061
# (713) 791-0700
# (713) 791-0700
# (713) 271-9000
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# http://www.plasticsurgery.org/md/michael-streitmann-md.html
# http://www.plasticsurgery.org/md/dr.ravi-somayazula.html
# http://www.plasticsurgery.org/md/erika-sato-md-houston-tx.html
# javascript:;
# javascript:;
# ----------page : 8---------
# Richard Vanik, MD, JD
# Bonnie Baldwin, MD
# Alfonso Barrera, MD
# Derek Lou, MD
# Melissa Crosby, MD
# Patrick Hsu, MD
# Rojan Amjadi, MD
# Ernest Layton, Jr., MD
# Rafi Bidros, MD
# Phileemon Payne, MD
# Christopher Patronella, MD
# Henry Mentz, MD
# (713) 981-7900
# (713) 791-1975
# (713) 468-5200
# (713) 932-7290
# (832) 939-8500
# (713) 633-4411
# (713) 465-6198
# (713) 337-5277
# (713) 467-0102
# (713) 461-8866
# (713) 799-9999
#
# javascript:;
# http://www.plasticsurgery.org/md/bonniebaldwinmd.html
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# http://www.plasticsurgery.org/md/phileemon-eric-payne-md.html
# javascript:;
# javascript:;

# %%
df["Highlighted Profile"] = names
df["Phone"]= phones
df["Website"]=websites

# %%
df
# Out:
#    State City           Highlighted Profile           Phone Email  \
# 0    NaN  NaN                Scott Reis, MD  (713) 791-0070   NaN
# 1    NaN  NaN             Carlton Perry, MD  (713) 522-8228   NaN
# 2    NaN  NaN  Forrest Roth, M.D., F.A.C.S.  (713) 559-9300   NaN
# 3    NaN  NaN                Edward Lee, MD  (713) 999-1321   NaN
# 4    NaN  NaN            Rukmini Rednam, MD  (713) 791-0700   NaN
# ..   ...  ...                           ...             ...   ...
# 91   NaN  NaN        Ernest Layton, Jr., MD  (713) 337-5277   NaN
# 92   NaN  NaN               Rafi Bidros, MD  (713) 467-0102   NaN
# 93   NaN  NaN           Phileemon Payne, MD  (713) 461-8866   NaN
# 94   NaN  NaN    Christopher Patronella, MD  (713) 799-9999   NaN
# 95   NaN  NaN               Henry Mentz, MD                   NaN
#
#                                               Website
# 0   http://www.plasticsurgery.org/md/dr-scott-reis...
# 1                                        javascript:;
# 2                                        javascript:;
# 3                                        javascript:;
# 4                                        javascript:;
# ..                                                ...
# 91                                       javascript:;
# 92                                       javascript:;
# 93  http://www.plasticsurgery.org/md/phileemon-eri...
# 94                                       javascript:;
# 95                                       javascript:;
#
# [96 rows x 6 columns]

# %%
df.to_csv()

# %%
url2 = "https://www.isaps.org/member-directory/"

# %%
# ------------TRials------------------------

# %%
for a in surgeon_name.find_all("a",class_ ="btn btn-link btn-xs ignore-click action enhancedBar"):
    print(a.get('href'))

# %%
for p in surgeon_name.find_all("p",itemprop="telephone"):
    print(p.text.strip())

# %%
for s in surgeon_name.find_all("h3"):
    print(s.text.strip())

# %%
for a in surgeon_name.find_all("tbody"):
    #if((a.find("a").get("href"))):
    print(a.find("a").get("href"))

# %%
for a in surgeon_name.find_all("a",class_ ="btn btn-link btn-xs ignore-click action enhancedBar"):
    if (a.get('href')==""):
        print("Unknown")
    else:
        print(a.get('href'))

# %%
surgeon_name.find_all("tbody")[10].find("a").get("onclick")

# %%
surgeon_name.find_all("tbody")[10].find("a")

# %%
p = surgeon_name.find_all("tbody")[10].find("a")
p

# %%
#browser.visit(s)

# %%
p = surgeon_name.find_all("tbody")[10].find("a").find("img").get("src")
p

# %%
names = []
phones = []
websites = []

for x in range(1,9):
    #print(x)
    url=f"https://find.plasticsurgery.org/default.aspx?lat=29.7598976&lon=-95.4073088&page={x}"
    browser.visit(url)
    html = browser.html
    soup = bs(html,'html.parser')
    #print(soup)
    
    surgeon = soup.find(id="findSurgeon").find(id="cphMainContent_divSearchResultsCol").find(class_="RadAjaxPanel")
    print(f"----------page : {x}---------")
    
    try:
        for s in surgeon.find_all("h3"):
            names.append(s.text.strip())
            print(s.text.strip())
    except:
        print("Oops!",sys.exc_info()[0],"occured")
        names.append("Unknown")
    
    try:
        for p in surgeon.find_all("p",itemprop="telephone"):
            phones.append(p.text.strip())
            print(p.text.strip())
    except:
        print("Oops!",sys.exc_info()[0],"occured")
        phones.append("Unknown")
        
    try:
        for a in surgeon.find_all("a",class_ ="btn btn-link btn-xs ignore-click action enhancedBar"):
            if(a.get('href')):
                websites.append(a.get('href'))
                print(a.get('href'))
            else:
                websites.append("Unknown")
       
    except:
        print("Oops!",sys.exc_info()[0],"occured")
        websites.append("Unknown")

# %%
 #browser.click_link_by_partial_text('Next')
    #try:
    #browser.click_link_by_partial_text(str(x))
    #except WebDriverException as e:
    #except (ElementDoesNotExist, WebDriverException) as e:
        #print(e)
    #except WebDriverException as e:
        #print("No element")
        #print(e)
        #print(traceback.exc_info)
    #for s in surgeon_name:
